# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.distplot(df.size ,bins= 10)
plt.show()

# %%
sns.distplot(df.total_bill , bins =5 )
plt.show()

# %%
sns.distplot(df.tip ,bins= 5)
plt.show()

# %%
sns.kdeplot(df.tip)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(df.total_bill)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(df.tip)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df.total_bill)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot( x = df.tip , y = df.total_bill )
plt.show()

# %%
sns.scatterplot(x =df.tip , y = df.total_bill  , hue ='size' , data= df)
plt.show()

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(x='tip',y='total_bill',  hue = 'size' ,  data= df)
plt.show()

# %%
sns.barplot(x='tip',y='total_bill',  hue = 'size' ,  data= df)
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill',  hue = 'size' ,  data= df , kind = 'kde')
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill',  hue = 'size' ,  data= df , kind = 'hist')
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill' ,  data= df , kind = 'reg')
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill' ,  data= df , kind = 'resid' )
plt.show()

# %%
sns.jointplot(x='tip',y='total_bill' ,  data= df , kind = "scatter" )
plt.show()

# %%
sns.pairplot(data = df ,hue = 'time')

# %%
sns.pairplot(data = df ,hue = 'day')

# %%
sns.pairplot(data = df ,hue = 'sex' )

# %%
sns.pairplot(data = df ,hue = 'smoker')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot( x= df.total_bill ,data = df)
plt.show()

# %%
sns.countplot( x= df.tip  , data = df)
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
sns.countplot(x = df.sex, data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot( x= 'day' , y = 'total_bill', data = df , hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.barplot( x= 'time' , y = 'total_bill', data = df , hue ='day')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot( x= 'smoker' , y = 'tip', data = df )
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.lmplot(x ='total_bill' , y = 'tip', data = df )

# %%
sns.violinplot(x='tip', y='total_bill',  data= df)
plt.show()

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.scatterplot(x ='total_bill' , y = 'total_bill' , data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='total_bill'>

# %%
sns.scatterplot(x ='total_bill' , y = 'tip' , data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.heatmap(df.corr(), annot=True , cmap = 'Oranges')
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...
